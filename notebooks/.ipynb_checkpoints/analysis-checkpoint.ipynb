# %% [markdown]
# # TCR Repertoire Sequencing — Literature Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the abstracts
df = pd.read_csv('../data/abstracts.csv')

print(f"Total abstracts: {len(df)}")
print(f"Year range: {df['year'].min()} – {df['year'].max()}")
print(f"\nAbstracts per year:")
print(df['year'].value_counts().sort_index())
# Out:
# Matplotlib is building the font cache; this may take a moment.
# Total abstracts: 200
# Year range: 2025 – 2026
#
# Abstracts per year:
# year
# 2025    139
# 2026     61
# Name: count, dtype: int64

# %%
# Plot abstracts per year
fig, ax = plt.subplots(figsize=(8, 5))
year_counts = df['year'].value_counts().sort_index()
ax.bar(year_counts.index.astype(str), year_counts.values, color='steelblue', edgecolor='white')
ax.set_title('PubMed Abstracts per Year\nQuery: TCR Repertoire Sequencing', fontsize=14)
ax.set_xlabel('Year')
ax.set_ylabel('Number of Abstracts')
for i, v in enumerate(year_counts.values):
    ax.text(i, v + 1, str(v), ha='center', fontsize=11)
plt.tight_layout()
plt.savefig('../data/abstracts_per_year.png', dpi=150)
plt.show()
print("Plot saved.")
# Out:
# Plot saved.

# %%
from collections import Counter
import re

# Combine all abstracts into one big string
all_text = ' '.join(df['abstract'].dropna().tolist()).lower()

# Remove common English stopwords and short words
stopwords = {
    'the', 'a', 'an', 'and', 'or', 'of', 'in', 'to', 'is', 'are', 'was',
    'were', 'for', 'with', 'this', 'that', 'these', 'those', 'we', 'our',
    'their', 'from', 'by', 'as', 'be', 'have', 'has', 'had', 'not', 'at',
    'on', 'also', 'which', 'but', 'it', 'its', 'than', 'may', 'can', 'cells',
    'cell', 'using', 'used', 'between', 'among', 'both', 'into', 'during',
    'however', 'been', 'high', 'low', 'significantly', 'including', 'showed'
}

# Tokenize and filter
words = re.findall(r'\b[a-z]{4,}\b', all_text)
filtered = [w for w in words if w not in stopwords]

# Count and display top 30
counter = Counter(filtered)
top_words = counter.most_common(30)

print("Top 30 most frequent words across all abstracts:\n")
for word, count in top_words:
    print(f"  {word:<25} {count}")
# Out:
# Top 30 most frequent words across all abstracts:
#
#   immune                    243
#   repertoire                184
#   receptor                  127
#   sequencing                121
#   patients                  116
#   cancer                    116
#   specific                  112
#   diversity                 91
#   antigen                   89
#   tumor                     85
#   tcrs                      81
#   responses                 80
#   blood                     72
#   analysis                  71
#   data                      71
#   study                     68
#   response                  66
#   single                    66
#   disease                   65
#   treatment                 62
#   based                     62
#   sequences                 58
#   clonal                    52
#   associated                51
#   human                     51
#   peripheral                50
#   repertoires               50
#   clonotypes                45
# ...

# %%
# Plot top 20 words
words_list = [w for w, c in top_words[:20]]
counts_list = [c for w, c in top_words[:20]]

fig, ax = plt.subplots(figsize=(10, 6))
ax.barh(words_list[::-1], counts_list[::-1], color='steelblue', edgecolor='white')
ax.set_title('Top 20 Most Frequent Words in TCR Repertoire Abstracts', fontsize=14)
ax.set_xlabel('Frequency')
plt.tight_layout()
plt.savefig('../data/top_words.png', dpi=150)
plt.show()
print("Plot saved.")
# Out:
# Plot saved.

# %%
# Load extracted features
features_df = pd.read_csv('../data/extracted_features.csv')

print(features_df.shape)
print("\nColumn names:")
print(features_df.columns.tolist())
print("\nFirst row:")
print(features_df.iloc[0])
# Out:
# (200, 9)
#
# Column names:
# ['study_type', 'sample_size', 'technology', 'disease_focus', 'key_finding', 'clinical_relevance', 'pmid', 'title', 'year']
#
# First row:
# study_type                                                computational
# sample_size                                                         NaN
# technology                                masked language model (tcrLM)
# disease_focus                                        melanoma, COVID-19
# key_finding           tcrLM, a lightweight masked language model pre...
# clinical_relevance                                                 high
# pmid                                                           41923632
# title                 A lightweight TcrLM model predicts T cell rece...
# year                                                               2026
# Name: 0, dtype: object

# %%
# Distribution of study types
print("Study type distribution:")
print(features_df['study_type'].value_counts())
print()

# Distribution of clinical relevance
print("Clinical relevance distribution:")
print(features_df['clinical_relevance'].value_counts())
print()

# Top disease focuses
print("Top disease focuses:")
print(features_df['disease_focus'].value_counts().head(10))
# Out:
# Study type distribution:
# study_type
# clinical          86
# basic_research    68
# computational     38
# review             6
# Name: count, dtype: int64
#
# Clinical relevance distribution:
# clinical_relevance
# high      161
# medium     35
# low         2
# Name: count, dtype: int64
#
# Top disease focuses:
# disease_focus
# none                                       36
# cancer                                     10
# COVID-19                                    8
# non-small cell lung cancer (NSCLC)          4
# colorectal cancer                           3
# pancreatic ductal adenocarcinoma (PDAC)     3
# tuberculosis                                3
# glioblastoma                                3
# melanoma                                    3
# lung cancer                                 3
# Name: count, dtype: int64

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

# Study type
study_counts = features_df['study_type'].value_counts()
axes[0].bar(study_counts.index, study_counts.values, color='steelblue', edgecolor='white')
axes[0].set_title('Study Type Distribution')
axes[0].set_xlabel('Study Type')
axes[0].set_ylabel('Count')
axes[0].tick_params(axis='x', rotation=15)

# Clinical relevance
rel_counts = features_df['clinical_relevance'].value_counts()
colors = ['#2ecc71', '#f39c12', '#e74c3c']
axes[1].bar(rel_counts.index, rel_counts.values, color=colors, edgecolor='white')
axes[1].set_title('Clinical Relevance Distribution')
axes[1].set_xlabel('Relevance')
axes[1].set_ylabel('Count')

# Top diseases (excluding 'none')
disease_counts = features_df[features_df['disease_focus'] != 'none']['disease_focus'].value_counts().head(8)
axes[2].barh(disease_counts.index[::-1], disease_counts.values[::-1], color='steelblue', edgecolor='white')
axes[2].set_title('Top Disease Focuses')
axes[2].set_xlabel('Count')

plt.tight_layout()
plt.savefig('../data/feature_distributions.png', dpi=150)
plt.show()
print("Plot saved.")
# Out:
# Plot saved.
